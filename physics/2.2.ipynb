# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# R = 1 Ohm
R_1 = 75 # Ohm
f = np.array([2., 3., 4., 5., 6., 7.14, 7.34, 7.54, 7.74, 7.94,
              8.14, 8.34, 9., 10., 11., 12., 13., 14., 15., 16]) # kHz
u = np.array([0.3, 0.4, 0.5, 0.8, 1.2, 2.6, 3.4, 4., 4.2,
              4., 3.6, 3.3, 2.2, 1.4, 1.1, 0.9, 0.7, 0.6, 0.5, 0.4]) # 10^-1 V
i = u * 1000 / R_1 / 10

# %%
fig = plt.figure(figsize=(15,7))

ax = fig.gca()
ax.set_xticks(np.arange(2, 16, 0.2), minor=True)
ax.set_yticks(np.arange(0., 6., 0.2), minor=True)
ax.grid(which='minor', alpha=0.4, linestyle='-')

plt.scatter(f, i, c='r', marker='^', label='R = 1 Ом')
plt.plot(f, i, color='r', label='Апроксимация для R = 1 Ом')

plt.xlabel(r'$f, kHz$', horizontalalignment='right', fontsize='x-large', x=1)
h = plt.ylabel(r'$I, mA$', verticalalignment='top', fontsize='x-large', horizontalalignment='right', y=1)
h.set_rotation(0)

plt.title('Зависимость I от f', fontsize=16)
plt.legend(fontsize=16)
plt.grid(ls='--')
plt.show()
