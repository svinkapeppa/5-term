# %%
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
# %matplotlib inline

# %%
def getk(x, y):
    return np.mean(x * y) / np.mean(x ** 2)

def geterr(x, y, n):
    return sqrt(((np.mean(y ** 2))/(np.mean(x ** 2)) - (getk(x, y) ** 2))) / sqrt(n)

# %%
z = np.linspace(0, 15, 31)
B = np.array([7.84, 7.94, 8.04, 8.1, 8.16, 8.19, 8.22, 8.24, 8.25,
              8.24, 8.21, 8.19, 8.14, 8.09, 8.02, 7.93, 7.81, 7.67,
              7.49, 7.18, 6.85, 6.44, 5.92, 5.32, 4.63, 3.91, 3.18,
              2.56, 2.14, 1.71, 1.3])

# %%
fig = plt.figure(figsize=(15,7))
ax = fig.gca()
ax.set_xticks(np.arange(0, 16, 0.2), minor=True)
ax.set_yticks(np.arange(1, 9, 0.2), minor=True)
ax.grid(which='minor', alpha=0.4, linestyle='-')

plt.plot(z, B, c='blue', linewidth=2)
plt.scatter(z, B, c='black', linewidth=3)
plt.xlabel("z, cm", horizontalalignment='right', fontsize='x-large', x=1)
h = plt.ylabel(r"B, mT", verticalalignment='top', fontsize='x-large', horizontalalignment='right', y=1)
h.set_rotation(0)

plt.title('Зависимость B от z', fontsize=16)
plt.grid(ls='--')
plt.savefig("First")
plt.show()

# %%
zstar = z[np.argmax(B)]

# %%
I = np.linspace(0.5, 2.5, 5)
B = np.array([8.25, 15.84, 23.2, 30.4, 38.1])
k = getk(I, B)
err = geterr(I, B, 4)

# %%
fig = plt.figure(figsize=(15,7))
ax = fig.gca()
ax.set_xticks(np.arange(0, 3, 0.025), minor=True)
ax.set_yticks(np.arange(8, 40, 0.5), minor=True)
ax.grid(which='minor', alpha=0.4, linestyle='-')

plt.plot(I, k * I, c='blue', linewidth=2)
plt.scatter(I, B, c='black', linewidth=3)
plt.xlabel("I, A", horizontalalignment='right', fontsize='x-large', x=1)
h = plt.ylabel("B, mT", verticalalignment='top', fontsize='x-large', horizontalalignment='right', y=1)
h.set_rotation(0)

plt.title('Зависимость B от I', fontsize=16)
plt.grid(ls='--')
plt.savefig("Second")
plt.show()

# %%
n = np.arange(1, 11)
B = np.array([291, 394, 433, 453, 463, 469, 472, 475, 476, 477])

# %%
fig = plt.figure(figsize=(15,7))
ax = fig.gca()
ax.set_xticks(np.arange(0, 11, 0.1), minor=True)
ax.set_yticks(np.arange(200, 500, 5), minor=True)
ax.grid(which='minor', alpha=0.4, linestyle='-')

plt.scatter(n, B, c='black', linewidth=3)
plt.plot(n, B, c='blue', linewidth=1)
plt.xlabel("n", horizontalalignment='right', fontsize='x-large', x=1)
h = plt.ylabel("B, mT", verticalalignment='top', fontsize='x-large', horizontalalignment='right', y=1)
h.set_rotation(0)

plt.title('Зависимость B от n', fontsize=16)
plt.grid(ls='--')
plt.savefig("Third")
plt.show()

# %%
m = np.array([2.944, 2.983, 3.02, 3.024, 3.051, 2.997, 3, 3.01, 2.98, 3.019])
M = np.mean(m)

# %%
z = np.linspace(0, 15, 31)
B = np.array([7.84, 7.94, 8.04, 8.1, 8.16, 8.19, 8.22, 8.24, 8.25,
              8.24, 8.21, 8.19, 8.14, 8.09, 8.02, 7.93, 7.81, 7.67,
              7.49, 7.18, 6.85, 6.44, 5.92, 5.32, 4.63, 3.91, 3.18,
              2.56, 2.14, 1.71, 1.3])
theory = np.array([7., 7.1, 7.1, 7.1, 7.2, 7.2, 7.2, 7.2, 7.2, 7.2, 7.2, 7.2,
                   7.2, 7.1, 7.1, 7.1, 7.0, 6.9, 6.8, 6.6, 6.3, 5.9, 5.3, 4.6,
                   3.7, 2.8, 2.0, 1.5, 1.06, 0.79, 0.6]) * 123 / 118

# %%
fig = plt.figure(figsize=(15,7))
ax = fig.gca()
ax.set_xticks(np.arange(0, 16, 0.2), minor=True)
ax.set_yticks(np.arange(1, 9, 0.2), minor=True)
ax.grid(which='minor', alpha=0.4, linestyle='-')

plt.plot(z, B, c='blue', linewidth=2)
plt.scatter(z, B, c='black', linewidth=3, label='Experiment')
plt.plot(z, theory, c='green', linewidth=2)
plt.scatter(z, theory, c='red', linewidth=3, label='Theory')

plt.xlabel("z, cm", horizontalalignment='right', fontsize='x-large', x=1)
h = plt.ylabel(r"B, mT", verticalalignment='top', fontsize='x-large', horizontalalignment='right', y=1)
h.set_rotation(0)

plt.title('Зависимость B от z', fontsize=16)
plt.legend()
plt.grid(ls='--')
plt.savefig("Forth")
plt.show()
